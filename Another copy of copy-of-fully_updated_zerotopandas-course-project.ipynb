# %% [markdown]
# # Shopping_trends-course-project-starter
#  **Introduction**
#
# T# Introduction
#
# This project focuses on analyzing customer shopping trends using the **Customer Shopping (Latest Trends) Dataset**, which was sourced from [Kaggle](https://www.kaggle.com/datasets/bhadramohit/customer-shopping-latest-trends-dataset). The dataset provides detailed information about customer purchases, including product categories, purchase amounts, demographic details, and shopping behaviors.
#
# ### Objective
# The primary goal of this project is to explore customer shopping behaviors and uncover meaningful insights that can drive decision-making. Specifically, the analysis aims to:
# 1. Understand purchasing patterns across different genders, age groups, and product categories.
# 2. Identify top-performing items, seasons, and customer segments.
# 3. Provide store-level insights, such as revenue generation and customer distribution.
# 4. Use visualizations and advanced metrics to make data-driven recommendations.
#
# ### Tools and Techniques
# This project leverages tools and techniques taught in the **[Data Analysis with Python: Zero to Pandas](https://zerotopandas.com)** course. Some of the key components include:
# - **Python Libraries**:
#   - `pandas` for data manipulation and analysis.
#   - `numpy` for numerical computations.
#   - `matplotlib` and `seaborn` for data visualization.
# - **Data Cleaning and Preparation**:
#   - Handling missing and invalid values.
#   - Converting data types and ensuring consistency.
# - **Exploratory Data Analysis (EDA)**:
#   - Summarizing data using descriptive statistics.
#   - Visualizing patterns and relationships between variables.
# - **Advanced Insights**:
#   - Grouping and aggregating data for segmented analysis.
#   - Merging datasets for richer context and insights.
#
# ### Learnings
# Through this project, I deepened my understanding of:
# - The end-to-end process of data analysis, from data cleaning to visualization.
# - Identifying trends and patterns in real-world datasets.
# - Using Python libraries to efficiently handle and analyze large datasets.
# - Communicating insights visually and effectively through plots and charts.
#
# This project showcases the practical application of the skills gained from the course, demonstrating how data analysis can help uncover actionable insights in consumer behavior.

# %% [markdown]
# ### How to run the code
#
# This is an executable [*Jupyter notebook*](https://jupyter.org) hosted on [Jovian.ml](https://www.jovian.ml), a platform for sharing data science projects. You can run and experiment with the code in a couple of ways: *using free online resources* (recommended) or *on your own computer*.
#
# #### Option 1: Running using free online resources (1-click, recommended)
#
# The easiest way to start executing this notebook is to click the "Run" button at the top of this page, and select "Run on Binder". This will run the notebook on [mybinder.org](https://mybinder.org), a free online service for running Jupyter notebooks. You can also select "Run on Colab" or "Run on Kaggle".
#
#
# #### Option 2: Running on your computer locally
#
# 1. Install Conda by [following these instructions](https://conda.io/projects/conda/en/latest/user-guide/install/index.html). Add Conda binaries to your system `PATH`, so you can use the `conda` command on your terminal.
#
# 2. Create a Conda environment and install the required libraries by running these commands on the terminal:
#
# ```
# conda create -n zerotopandas -y python=3.8
# conda activate zerotopandas
# pip install jovian jupyter numpy pandas matplotlib seaborn opendatasets --upgrade
# ```
#
# 3. Press the "Clone" button above to copy the command for downloading the notebook, and run it on the terminal. This will create a new directory and download the notebook. The command will look something like this:
#
# ```
# jovian clone notebook-owner/notebook-id
# ```
#
#
#
# 4. Enter the newly created directory using `cd directory-name` and start the Jupyter notebook.
#
# ```
# jupyter notebook
# ```
#
# You can now access Jupyter's web interface by clicking the link that shows up on the terminal or by visiting http://localhost:8888 on your browser. Click on the notebook file (it has a `.ipynb` extension) to open it.

# %% [markdown]
# ## Downloading the Dataset
#
# Downloading the Dataset
# To begin working with the project, you need to download the required dataset. Here’s how you can do it:
#
# Choose a Dataset:
#
# For this project, the dataset being used is the Customer Shopping (Latest Trends) Dataset sourced from Kaggle.
# You can explore similar datasets on Kaggle at this link.
# Download Using the opendatasets Library:
#
# The easiest way to download datasets from Kaggle programmatically is by using the Python library opendatasets. You can install it using:
# bash

# %%
pip install opendatasets

# %% [markdown]
# To download the dataset, simply use

# %%
import opendatasets as od
od.download('https://www.kaggle.com/datasets/bhadramohit/customer-shopping-latest-trends-dataset')
# Out:
# Skipping, found downloaded files in "./customer-shopping-latest-trends-dataset" (use force=True to force download)

# %% [markdown]
# Ensure the Dataset is in CSV Format:
#
# The dataset should be in a CSV format, containing at least three columns and 150 rows to allow for meaningful analysis.

# %% [markdown]
# Locate the Downloaded Files:
#
# The dataset will be saved in a directory, which can be listed using:

# %%
import os
os.listdir('./customer-shopping-latest-trends-dataset')
# Out:
# ['shopping_trends.csv']

# %% [markdown]
# Make sure you have set up your Kaggle credentials in your environment for opendatasets to work. If you need help setting up, follow the steps provided in the opendatasets documentation.
#
# This will ensure you have the dataset downloaded and ready for analysis.

# %%
# !pip install jovian opendatasets --upgrade --quiet

# %% [markdown]
# Let's begin by downloading the data, and listing the files within the dataset.

# %%
# Changed"
dataset_url = "https://www.kaggle.com/datasets/bhadramohit/customer-shopping-latest-trends-dataset"

# %%
import opendatasets as od
od.download(dataset_url)

import opendatasets as od
od.download(dataset_url)
# Out:
# Skipping, found downloaded files in "./customer-shopping-latest-trends-dataset" (use force=True to force download)
# Skipping, found downloaded files in "./customer-shopping-latest-trends-dataset" (use force=True to force download)

# %% [markdown]
# The dataset has been downloaded and extracted.

# %%
# Change this

data_dir = './customer-shopping-latest-trends-dataset'
data_dir
# Out:
# './customer-shopping-latest-trends-dataset'

# %%
import os
#os.listdir(data_dir)

# %%
os.listdir(data_dir)
# Out:
# ['shopping_trends.csv']

# %% [markdown]
# Let us save and upload our work to Jovian before continuing.

# %%
project_name = "shopping_trends-course-project-starter" # change this (use lowercase letters and hyphens only)

# %%
# !pip install jovian --upgrade -q

# %%
import jovian

# %%
jovian.commit(project=project_name)
# Out:
# [jovian] Detected Colab notebook...
# [jovian] jovian.commit() is no longer required on Google Colab. If you ran this notebook from Jovian,
# then just save this file in Colab using Ctrl+S/Cmd+S and it will be updated on Jovian.
# Also, you can also delete this cell, it's no longer necessary.

# %% [markdown]
# ## Data Preparation and Cleaning
#
# we are doing all the below taskd in oreder:
#
#  1.Load the dataset into a data frame using Pandas
# 2.Explore the number of rows & columns, ranges of values etc.
# 3.Handle missing, incorrect and invalid data
# 4.Perform any additional steps (parsing dates, creating additional columns, merging multiple dataset etc.)

# %% [markdown]
# LOAD THE DATASET INTO A PANDAS DATAFRAME AND CALLING PANDAS AND NUMPY LIBRARY

# %%
import pandas as pd
import numpy as np

shopping_df = pd.read_csv("customer-shopping-latest-trends-dataset/shopping_trends.csv")

# %% [markdown]
# Explore the number of rows & columns, ranges of values

# %%
shopping_df.shape # the dtaset has 3900 rows and 19 columns
# Out:
# (3900, 19)

# %%
shopping_df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
shopping_df.info() # get a summary of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %% [markdown]
# CHECKING IF THE DATASET HAS MISSING VALUES

# %%
shopping_df.isnull().sum() # check for the sum of  missing values in each column
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# get information about the statics

# %%
shopping_df.describe() #get information about the statics
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %% [markdown]
# get the values in age coloumn

# %%
shopping_df.Age.unique() # get the values in age coloumn
# Out:
# array([55, 19, 50, 21, 45, 46, 63, 27, 26, 57, 53, 30, 61, 65, 64, 25, 52,
#        66, 31, 56, 18, 38, 54, 33, 36, 35, 29, 70, 69, 67, 20, 39, 42, 68,
#        49, 59, 47, 40, 41, 48, 22, 24, 44, 37, 58, 32, 62, 51, 28, 43, 34,
#        23, 60])

# %% [markdown]
# accessing to the slicing rows between 7 to 10

# %%
shopping_df.loc[7:10] # accessing to the slicing rows between 7 to 10
# Out:
#     Customer ID  Age Gender Item Purchased     Category  \
# 7             8   27   Male         Shorts     Clothing
# 8             9   26   Male           Coat    Outerwear
# 9            10   57   Male        Handbag  Accessories
# 10           11   53   Male          Shoes     Footwear
#
#     Purchase Amount (USD)       Location Size     Color  Season  \
# 7                      34      Louisiana    L  Charcoal  Winter
# 8                      97  West Virginia    L    Silver  Summer
# 9                      31       Missouri    M      Pink  Spring
# 10                     34       Arkansas    L    Purple    Fall
#
#     Review Rating Subscription Status Payment Method   Shipping Type  \
# 7             3.2                 Yes     Debit Card   Free Shipping
# 8             2.6                 Yes          Venmo         Express
# 9             4.8                 Yes         PayPal  2-Day Shipping
# 10            4.1                 Yes    Credit Card    Store Pickup
#
# ...

# %% [markdown]
# Handle missing, incorrect and invalid data

# %%
# Fill missing values for numerical columns with the mean
for col in shopping_df.select_dtypes(include = "number").columns:
    if shopping_df[col].isnull().sum() > 0 :
        shopping_df[col].fillna(shopping_df[col].mean(), inplace = True)

# %%
# filling the missing values  for categorical columns with the mode

for col in shopping_df.select_dtypes(include ="object").columns:
    if shopping_df[col].isnull().sum() > 0:
        shopping_df[col].fillna(shopping_df[col].mode(), inplace = True)

# %% [markdown]
# This checks all numerical columns and converts invalid values to NaN e.g., if a number column has "abc", it will become NaN
#
# An invalid numeric value is any value that cannot be interpreted as a number. Examples include:
#
# Strings: "abc", "N/A", "unknown".
# Special characters: "@!", "#$$".
# Dates or mixed data: "01/01/2023", "45abc".
# Without errors='coerce', these values would cause an error when trying to convert them to numbers.

# %%
for col in shopping_df.select_dtypes(include ="number").columns:
    shopping_df[col] = pd.to_numeric(shopping_df[col],errors = "coerce")

# %% [markdown]
# Fix Invalid Data in Categorical Columns:
#
# Replace invalid or placeholder values like empty strings ('') or "Unknown" with NaN.

# %%
for col in shopping_df.select_dtypes(include ="object").columns:
    shopping_df[col] = shopping_df[col].replace([" ","Unknown"],pd.NA,inplace =True)
# Out:
# <ipython-input-29-50655d3e367e>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   shopping_df[col] = shopping_df[col].replace([" ","Unknown"],pd.NA,inplace =True)

# %%
shopping_df
# Out:
#       Customer ID  Age Gender Item Purchased Category  Purchase Amount (USD)  \
# 0               1   55   None           None     None                     53
# 1               2   19   None           None     None                     64
# 2               3   50   None           None     None                     73
# 3               4   21   None           None     None                     90
# 4               5   45   None           None     None                     49
# ...           ...  ...    ...            ...      ...                    ...
# 3895         3896   40   None           None     None                     28
# 3896         3897   52   None           None     None                     49
# 3897         3898   46   None           None     None                     33
# 3898         3899   44   None           None     None                     77
# 3899         3900   52   None           None     None                     81
#
# ...

# %% [markdown]
# Key Takeaway
# data.shape ensures flexibility by dynamically setting the threshold based on the DataFrame's structure.
# thresh defines how much missing data is acceptable, helping retain rows with sufficient information.

# %%
#Remove rows where more than 50% of the columns have missing values

#shopping_df.dropna(thresh = 0.5 * shopping_df.shape[1], inplace = True)

# %%
shopping_df.Gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
# final check for existing missing values
print("\nFinal Missing Values:")
print(shopping_df.isnull().sum())

print("\nCleaned Dataset Preview:")
print(shopping_df.head())
# Out:
# Final Missing Values:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64
#
# Cleaned Dataset Preview:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# ...

# %% [markdown]
# Perform any additional steps (parsing dates, creating additional columns, merging multiple dataset etc.)

# %% [markdown]
# return a specific value at specific row and column with at

# %%
shopping_df.at[99,"Size"]
# Out:
# 'XL'

# %% [markdown]
# access multiple values from the same row (e.g., "Age" and "Gender" from row 2), you should use .loc

# %%
shopping_df.loc[2, ["Age", "Gender"]]
# Out:
# Age         50
# Gender    Male
# Name: 2, dtype: object

# %% [markdown]
# calculate the total amount paid for items per season in dataset

# %%
total_amount_paid_per_season = shopping_df.groupby("Season")["Purchase Amount (USD)"].sum()

total_amount_paid_per_season
# Out:
# Season
# Fall      60018
# Spring    58679
# Summer    55777
# Winter    58607
# Name: Purchase Amount (USD), dtype: int64

# %% [markdown]
# what is the total_amounts paid for Blouses per Gender

# %%
#total_amounts_for_blouses_per_gender = shopping_df.groupby("Gender")shopping_df[Item Purchased][Blouse].sum()
Blouse_amount = shopping_df[shopping_df["Item Purchased"] == "Blouse"]
Blouse_amount
# Out:
#       Customer ID  Age  Gender Item Purchased  Category  \
# 0               1   55    Male         Blouse  Clothing
# 4               5   45    Male         Blouse  Clothing
# 35             36   54    Male         Blouse  Clothing
# 50             51   49    Male         Blouse  Clothing
# 66             67   31    Male         Blouse  Clothing
# ...           ...  ...     ...            ...       ...
# 3787         3788   37  Female         Blouse  Clothing
# 3801         3802   26  Female         Blouse  Clothing
# 3807         3808   38  Female         Blouse  Clothing
# 3828         3829   42  Female         Blouse  Clothing
# 3846         3847   57  Female         Blouse  Clothing
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 4                        49         Oregon    M  Turquoise  Spring
# 35                       33  Massachusetts    M       Cyan  Summer
# ...

# %%
total_amount_blouse =Blouse_amount.groupby("Gender")["Purchase Amount (USD)"].sum()

total_amount_blouse
# Out:
# Gender
# Female    4016
# Male      6394
# Name: Purchase Amount (USD), dtype: int64

# %% [markdown]
# Adding total_amount_blouse column to the DataFrame

# %%
shopping_df["total_amount_blouse"] = shopping_df["Gender"].map(total_amount_blouse)
shopping_df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# BOOLEAN EXPERESSION AS AN INDEX INTO DATAFRAME

# %%
high_purchase_amount = shopping_df["Purchase Amount (USD)"] > 50
high_purchase_amount
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 3895    False
# 3896    False
# 3897    False
# 3898     True
# 3899     True
# Name: Purchase Amount (USD), Length: 3900, dtype: bool

# %%
shopping_df["purchase_over_fifty"] = shopping_df["Purchase Amount (USD)"] > 50 # add a new colomin to dataset for purchases over 50

shopping_df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  ...  \
# 0                        53       Kentucky    L       Gray  Winter  ...
# 1                        64          Maine    L     Maroon  Winter  ...
# ...

# %% [markdown]
# display 5 rows only

# %%
from IPython.display import display

with pd.option_context("display.max_rows", 5):

    display(shopping_df[shopping_df["Purchase Amount (USD)"] > 60])
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# ...           ...  ...     ...            ...          ...
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size   Color  Season  ...  \
# 1                        64          Maine    L  Maroon  Winter  ...
# 2                        73  Massachusetts    S  Maroon  Spring  ...
# ...                     ...            ...  ...     ...     ...  ...
# 3898                     77      Minnesota    S   Brown  Summer  ...
# 3899                     81     California    M   Beige  Spring  ...
#
#       Subscription Status Payment Method  Shipping Type Discount Applied  \
# 1                     Yes  Bank Transfer        Express              Yes
# ...

# %%
# DISPLAY 5 COLUMNS ONLY
from IPython.display import display
import pandas as pd

# DISPLAY min 5 rows
with pd.option_context("display.min_rows", 5):
    display(shopping_df[shopping_df["Purchase Amount (USD)"] > 60])
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# ...           ...  ...     ...            ...          ...
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size   Color  Season  ...  \
# 1                        64          Maine    L  Maroon  Winter  ...
# 2                        73  Massachusetts    S  Maroon  Spring  ...
# ...                     ...            ...  ...     ...     ...  ...
# 3898                     77      Minnesota    S   Brown  Summer  ...
# 3899                     81     California    M   Beige  Spring  ...
#
#       Subscription Status Payment Method  Shipping Type Discount Applied  \
# 1                     Yes  Bank Transfer        Express              Yes
# ...

# %% [markdown]
# sort the purchase per dy bases on age

# %%
shopping_df.sort_values("Age", ascending= False).head(20)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 229           230   70    Male        Sandals     Footwear
# 2778         2779   70  Female           Belt  Accessories
# 2618         2619   70    Male        Handbag  Accessories
# 2665         2666   70  Female        T-shirt     Clothing
# 2017         2018   70    Male          Socks     Clothing
# 2702         2703   70  Female          Shoes     Footwear
# 1956         1957   70    Male          Socks     Clothing
# 1055         1056   70    Male         Jacket    Outerwear
# 1936         1937   70    Male        Jewelry  Accessories
# 597           598   70    Male        Jewelry  Accessories
# 3802         3803   70  Female          Scarf  Accessories
# 3002         3003   70  Female           Belt  Accessories
# 584           585   70    Male          Socks     Clothing
# 2800         2801   70  Female          Shirt     Clothing
# 3822         3823   70  Female            Hat  Accessories
# ...

# %% [markdown]
# REPLACE 228 ROW  AND PURCHSE AMOUNT ELEMANT WITH AVERAGE OF THE PREVIOUS AND NEXT VALUES OF THE SAME COLUMN

# %%
shopping_df.at[229, "Purchase Amount (USD)"] = (shopping_df.at[228 ,"Purchase Amount (USD)"] + shopping_df.at[230, "Purchase Amount (USD)"]) /2
# Out:
# <ipython-input-87-7fbeb992a5f7>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '83.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   shopping_df.at[229, "Purchase Amount (USD)"] = (shopping_df.at[228 ,"Purchase Amount (USD)"] + shopping_df.at[230, "Purchase Amount (USD)"]) /2

# %%
shopping_df.loc[227:231, ["Purchase Amount (USD)"]]
# Out:
#      Purchase Amount (USD)
# 227                   90.0
# 228                   79.0
# 229                   83.5
# 230                   88.0
# 231                   26.0

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Detected Colab notebook...
# [jovian] jovian.commit() is no longer required on Google Colab. If you ran this notebook from Jovian,
# then just save this file in Colab using Ctrl+S/Cmd+S and it will be updated on Jovian.
# Also, you can also delete this cell, it's no longer necessary.

# %% [markdown]
# ## Exploratory Analysis and Visualization
# # Exploratory Analysis and Visualization
# **Exploratory Analysis and Visualization** section, explicitly mentioning scatter plots:
#
# ---
#
# ### **Exploratory Analysis and Visualization**
#
# This project focuses on leveraging the **Customer Shopping (Latest Trends) Dataset** to uncover actionable insights through detailed data exploration and visualization. The objective is to understand customer behaviors, identify patterns, and provide clear trends that inform decision-making.
#
# ---
#
# ### **Goals of Exploratory Data Analysis (EDA):**
# #### **1. Data Overview:**
# - **Assess Dataset Structure:** Analyze the dataset’s dimensions and key features.
# - **Data Cleaning:** Handle missing, invalid, or inconsistent data to ensure accuracy and reliability.
#
# #### **2. Numerical Feature Analysis:**
# - **Key Metrics:** Investigate features such as `Purchase Amount (USD)` and `Age`.
# - **Distributions:** Use histograms, scatter plots, and box plots to understand the spread of data and detect outliers.
#
# #### **3. Categorical Feature Analysis:**
# - **Focus Variables:** Explore categories like `Gender`, `Season`, `Item Purchased`, and `Subscription Status`.
# - **Visualization:** Employ bar charts and pie charts to display the frequency and proportions of categories.
#
# #### **4. Relationships Between Variables:**
# - **Interaction Analysis:** Explore correlations between `Age`, `Purchase Amount`, and `Review Rating`.
# - **Scatter Plots:** Highlight patterns between numerical and categorical data (e.g., `Age` vs. `Purchase Amount` with `Gender` as hue).
# - **Line Charts:** Observe trends over time or across categories (e.g., `Average Purchase Amount by Season`).
#
# #### **5. Advanced Visualizations:**
# Incorporate creative charts to emphasize insights:
# - **Heatmaps:** Analyze interactions between `Payment Method` and `Shipping Type`.
# - **Segmented Scatter Plots:** Show how discounts affect purchasing patterns across age groups.
# - **Stacked Bar Charts:** Compare purchase frequencies across locations and categories.
#
# ---
#
# ### **Key Insights Derived:**
# 1. **Behavioral Patterns:**
#    - Seasonal peaks in spending, with higher purchases during `Winter`.
#    - Gender-specific trends, such as females favoring `Clothing` categories.
# 2. **Demographics:**
#    - Younger age groups (`18-35`) exhibit higher spending behavior.
#    - Subscription holders are more likely to spend over $50 per transaction.
# 3. **Spending Habits:**
#    - Higher purchase amounts observed with credit card payments.
#    - Discount usage influences repeat purchases, particularly among loyal customers.
#
# ---
#
# ### **Tools and Techniques:**
# - **Data Manipulation:** Used `pandas` for grouping, aggregation, and creating calculated columns.
# - **Visualization:** Deployed `matplotlib` and `seaborn` for charts like scatter plots, heatmaps, and line charts.
# - **Statistical Analysis:** Applied numerical summaries (e.g., mean, median) to uncover hidden patterns.
#
# ---
#
# ### **Examples of Visualizations:**
# 1. **Scatter Plot:**
#    - **Question:** How does age relate to purchase amount, and does this differ by gender?
#    - **Visualization:** A scatter plot with `Age` on the x-axis, `Purchase Amount (USD)` on the y-axis, and `Gender` as hue.
#
# 2. **Bar Chart:**
#    - **Question:** What proportion of purchases over $50 comes from subscription holders?
#    - **Visualization:** A bar chart showing the proportion by subscription status.
#
# 3. **Line Chart:**
#    - **Question:** How does the average purchase amount vary across seasons?
#    - **Visualization:** A line chart segmented by gender.
#
# 4. **Heatmap:**
#    - **Question:** What are the most common payment method and shipping type combinations?
#    - **Visualization:** A heatmap displaying counts for each combination.
#
# 5. **Box Plot:**
#    - **Question:** How does the distribution of purchase amounts vary by season and gender?
#    - **Visualization:** A box plot to show ranges and medians.
#
# ---

# %% [markdown]
# Let's begin by importing`matplotlib.pyplot` and `seaborn`.

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Purchase Frequency Heatmap by Payment Method and Shipping Type
# Question: "Which combinations of payment methods and shipping types are most common?"

# %%
# Heatmap
heatmap_data = shopping_df.pivot_table(
    values='Customer ID',
    index='Payment Method',
    columns='Shipping Type',
    aggfunc='count'
)

plt.figure(figsize=(10, 8))
sns.heatmap(heatmap_data, annot=True, cmap='Oranges', fmt=".0f", linewidths=0.5)
plt.title('Purchase Frequency by Payment Method and Shipping Type', fontsize=16)
plt.xlabel('Shipping Type', fontsize=14)
plt.ylabel('Payment Method', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# How does the total number of purchases vary across age groups?"

# %%
shopping_df['Age Group'] = pd.cut(
    shopping_df['Age'], bins=[0, 18, 35, 50, 65, 100], labels=['<18', '18-35', '36-50', '51-65', '65+']
)

total_purchases_age_group = shopping_df.groupby('Age Group')['Customer ID'].count()

plt.figure(figsize=(8, 6))
total_purchases_age_group.plot(marker='s', linestyle='--', color='green')
plt.title('Total Purchases by Age Group', fontsize=16)
plt.xlabel('Age Group', fontsize=14)
plt.ylabel('Total Purchases', fontsize=14)
plt.grid(alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-116-f27e71690ff9>:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   total_purchases_age_group = shopping_df.groupby('Age Group')['Customer ID'].count()

# %% [markdown]
#   What is the proportion of purchases over $50 across different subscription statuses?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group by 'Subscription Status' and calculate the proportion of purchases over $50
purchase_over_50_proportion = shopping_df.groupby('Subscription Status')['purchase_over_fifty'].mean()

# Plot the results
plt.figure(figsize=(10, 6))
bars = purchase_over_50_proportion.plot(kind='bar', color=['cornflowerblue', 'salmon'], edgecolor='black', alpha=0.9)

# Add annotations for the bar values
for i, value in enumerate(purchase_over_50_proportion):
    plt.text(i, value + 0.02, f'{value:.2%}', ha='center', va='bottom', fontsize=10, color='black')

# Add descriptive labels and titles
plt.title('Proportion of Purchases Over $50 by Subscription Status', fontsize=16)
plt.xlabel('Subscription Status', fontsize=14)
plt.ylabel('Proportion of Purchases Over $50', fontsize=14)
plt.xticks(rotation=0, fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# How do review ratings differ across product categories and genders

# %%
heatmap_data = shopping_df.pivot_table(
    values='Review Rating',
    index='Category',
    columns='Gender',
    aggfunc='mean'
)

plt.figure(figsize=(10, 8))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap='Blues', linewidths=0.5)
plt.title('Average Review Rating by Product Category and Gender', fontsize=16)
plt.xlabel('Gender', fontsize=14)
plt.ylabel('Product Category', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# Do customers who receive discounts tend to make more previous purchases, and how does this vary by age?"

# %% [markdown]
# Box Plot: Variability of Purchase Amounts by Gender and Season
# A box plot displays the range, median, and variability of purchase amounts.

# %%
import seaborn as sns

# Create box plot
plt.figure(figsize=(12, 6))
sns.boxplot(data=shopping_df, x='Season', y='Purchase Amount (USD)', hue='Gender', palette='Set2')

# Add titles and labels
plt.title('Distribution of Purchase Amounts by Season and Gender', fontsize=16)
plt.xlabel('Season', fontsize=14)
plt.ylabel('Purchase Amount (USD)', fontsize=14)
plt.legend(title="Gender", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
#  Trends of Average Purchase Amount Across Seasons
# A line chart provides a clear view of how average spending changes across seasons, separated by gender.

# %%
import matplotlib.pyplot as plt

# Group data by Season and Gender, calculate average purchase amount
avg_purchase_season_gender = shopping_df.groupby(['Season', 'Gender'])['Purchase Amount (USD)'].mean().unstack()

# Plotting the line chart
plt.figure(figsize=(10, 6))
for gender in avg_purchase_season_gender.columns:
    plt.plot(avg_purchase_season_gender.index, avg_purchase_season_gender[gender], marker='o', label=gender)

# Add titles and labels
plt.title('Average Purchase Amount by Season and Gender', fontsize=16)
plt.xlabel('Season', fontsize=14)
plt.ylabel('Average Purchase Amount (USD)', fontsize=14)
plt.legend(title="Gender", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# What proportion of total purchases is made by each gender?

# %%
gender_proportion = shopping_df['Gender'].value_counts()

plt.figure(figsize=(8, 6))
gender_proportion.plot.pie(autopct='%1.1f%%', startangle=90, explode=[0.05, 0], colors=['skyblue', 'pink'])
plt.title('Proportion of Purchases by Gender', fontsize=16)
plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# Let us save and upload our work to Jovian before continuing

# %%
import jovian

# %%
jovian.commit()

# %% [markdown]
# ## Asking and Answering Questions
#
# ## Asking and Answering Questions
#
# This section focuses on using the dataset to address specific questions and uncover actionable insights. The goal is to apply the cleaned and prepared data to solve practical problems, validate hypotheses, or explore interesting trends.
#
# ### Purpose:
# 1. Identify trends and patterns that are not immediately visible from raw data.
# 2. Answer questions relevant to customer behavior, product popularity, and financial performance.
# 3. Use visualizations and computations to make insights accessible and interpretable.
#
# ### Key Questions Addressed in the Code:
#
# 1. **What is the average purchase amount for blouses per week?**
#    - Calculate the weekly average purchase for the specific item category "Blouse" by dividing the total purchase amount by the frequency of purchases.
#
# 2. **What is the total spending by gender?**
#    - Use grouping and aggregation to find the total purchase amount segmented by gender and add this as a new column for further analysis.
#
# 3. **What are the top 10 highest purchases?**
#    - Sort the dataset by purchase amounts in descending order to identify the customers or transactions with the highest spending.
#
# 4. **How can multiple datasets be combined for richer insights?**
#    - Demonstrate merging two datasets (customer purchases and store details) to analyze store-level performance and managerial impact on total purchases.
#
# 5. **How do different variables interact visually?**
#    - Use a combination of boxplots, bar charts, and scatter plots to explore relationships between variables like gender, subscription status, age, and purchase amounts.
#
# ### Approach:
# - **Exploration**:
#   Start by asking specific questions based on the columns and variables in the dataset.
# - **Implementation**:
#   Use Python libraries (`pandas`, `numpy`, `matplotlib`, `seaborn`) to compute results and generate visualizations.
# - **Interpretation**:
#   Analyze the results and derive conclusions that are meaningful and applicable.
#
# ### Examples from the Code:
# - A **bar chart** showing the distribution of purchases by gender and subscription status.
# - A **line plot** illustrating how average purchase amounts vary with age.
# - Grouped metrics like total blouse purchases by season and gender.
# - Combining datasets to find the store with the highest total revenue and its manager.
#
# This systematic approach to asking and answering questions helps provide a deeper understanding of the dataset and facilitates data-driven decision-making.

# %%
shopping_df

# %% [markdown]
# #### Q1:
#
# WHAT IS THE AVERAGE PURCHASE FOR BLOUSES PER WEEK

# %%
shopping_df["Frequency of Purchases"] = pd.to_numeric(shopping_df["Frequency of Purchases"], errors="coerce")
shopping_df["Purchase Amount (USD)"] = pd.to_numeric(shopping_df["Purchase Amount (USD)"], errors="coerce")

# Step 2: Filter for 'Blouse' purchases
blouse_purchases = shopping_df[shopping_df["Item Purchased"] == "Blouse"]

# Step 3: Calculate weekly average only for 'Blouse' rows
shopping_df["Weekly_Average"] = None  # Initialize column
shopping_df.loc[shopping_df["Item Purchased"] == "Blouse", "Weekly_Average"] = (
    blouse_purchases["Purchase Amount (USD)"] / blouse_purchases["Frequency of Purchases"]
)

# Display the updated DataFrame
print(shopping_df)

# %% [markdown]
# delete th Weekly Average column

# %%
shopping_df.drop("Weekly Average", inplace =True ,axis =1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-127-93daaa867310> in <cell line: 1>()
# ----> 1 shopping_df.drop("Weekly Average", inplace =True ,axis =1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
shopping_df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  ...  \
# 0                      53.0       Kentucky    L       Gray  Winter  ...
# 1                      64.0          Maine    L     Maroon  Winter  ...
# ...

# %% [markdown]
# #### Q2: TODO - ask a question here and answer it below
#
# wht is the total spending by gender

# %%
total_SPENDING_Gender = shopping_df.groupby("Gender")["Purchase Amount (USD)"].sum()

total_SPENDING_Gender
# Out:
# Gender
# Female     75191.0
# Male      157945.5
# Name: Purchase Amount (USD), dtype: float64

# %% [markdown]
# adding total_SPENDING_Gender column to the DataFrame

# %%
shopping_df["total_SPENDING_Gender"] = shopping_df["Gender"].map(total_SPENDING_Gender)
shopping_df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  ...  \
# 0                      53.0       Kentucky    L       Gray  Winter  ...
# 1                      64.0          Maine    L     Maroon  Winter  ...
# ...

# %% [markdown]
# #### Q3: TODO -
#
# visualising 6 plots for the dataset as subplots

# %%
shopping_df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  ...  \
# 0                      53.0       Kentucky    L       Gray  Winter  ...
# 1                      64.0          Maine    L     Maroon  Winter  ...
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(18, 10))

# Boxplot: Distribution of purchase amount by gender
sns.boxplot(x="Gender", y="Purchase Amount (USD)", data=shopping_df, palette="coolwarm", ax=axes[0, 0])
axes[0, 0].set_title("Distribution of Purchase Amount by Gender", fontsize=14)
axes[0, 0].set_xlabel("Gender", fontsize=12)
axes[0, 0].set_ylabel("Purchase Amount (USD)", fontsize=12)

# Countplot: Count of purchases by gender and subscription status
sns.countplot(x="Gender", hue="Subscription Status", data=shopping_df, palette="Set2", ax=axes[0, 1])
axes[0, 1].set_title("Count of Purchases by Gender and Subscription Status", fontsize=14)
axes[0, 1].set_xlabel("Gender", fontsize=12)
axes[0, 1].set_ylabel("Count of Purchases", fontsize=12)
axes[0, 1].legend(title="Subscription Status", loc="upper right")

# Lineplot: Average purchase amount by age
age_avg_purchase = shopping_df.groupby("Age")["Purchase Amount (USD)"].mean().reset_index()
sns.lineplot(x="Age", y="Purchase Amount (USD)", data=age_avg_purchase, marker="o", color="purple", ax=axes[1, 0])
axes[1, 0].set_title("Average Purchase Amount by Age", fontsize=14)
axes[1, 0].set_xlabel("Age", fontsize=12)
axes[1, 0].set_ylabel("Average Purchase Amount (USD)", fontsize=12)

# Stacked Bar Plot: Purchase frequency by location and category
location_category_counts = shopping_df.groupby(["Location", "Category"]).size().unstack(fill_value=0)
location_category_counts.plot(kind="bar", stacked=True, colormap="viridis", ax=axes[1, 1])
axes[1, 1].set_title("Purchase Frequency by Location and Category", fontsize=14)
axes[1, 1].set_xlabel("Location", fontsize=12)
axes[1, 1].set_ylabel("Purchase Frequency", fontsize=12)
axes[1, 1].legend(title="Category", fontsize=10)

# Adjust layout for better spacing
plt.tight_layout(pad=4)
plt.show()
# Out:
# <ipython-input-121-9ba137295359>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Gender", y="Purchase Amount (USD)", data=shopping_df, palette="coolwarm", ax=axes[0, 0])

# %% [markdown]
# #### Q4: TODO - ask a question here and answer it below
#
#  finding top 10 highest purchases

# %%
 # Sort the DataFrame by 'Purchase Amount (USD)' in descending order
high1 = shopping_df.sort_values("Purchase Amount (USD)", ascending=False).head(10)

# Display the top 10 rows
high1
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 861           862   46    Male          Skirt     Clothing
# 2430         2431   20    Male         Jacket    Outerwear
# 2802         2803   22  Female           Coat    Outerwear
# 615           616   67    Male        Sandals     Footwear
# 2214         2215   50    Male           Belt  Accessories
# 2807         2808   56  Female         Hoodie     Clothing
# 769           770   52    Male          Socks     Clothing
# 204           205   24    Male       Sneakers     Footwear
# 2842         2843   28  Female           Coat    Outerwear
# 95             96   37    Male       Sneakers     Footwear
#
#       Purchase Amount (USD)      Location Size     Color  Season  ...  \
# 861                   100.0      Virginia   XL     Green  Spring  ...
# 2430                  100.0  North Dakota   XL     White  Summer  ...
# 2802                  100.0        Hawaii    L       Red    Fall  ...
# ...

# %% [markdown]
# #### Q5: TODO - ask a question here and answer it below
#
# merging to slcing datasets

# %%
import pandas as pd

# Dataset 1: Customer Purchases
shop_data = {
    "Customer ID": ["C001", "C002", "C003", "C004", "C005"],
    "Item Purchased": ["Blouse", "Shirt", "Pants", "Skirt", "Dress"],
    "Purchase Amount (USD)": [200, 50, 300, 150, 400],
    "Store": ["Store A", "Store B", "Store A", "Store C", "Store D"]
}
shop_df = pd.DataFrame(shop_data)

# Dataset 2: Store Details
store_info_data = {
    "Store": ["Store A", "Store B", "Store C", "Store D"],
    "Location": ["New York", "Los Angeles", "Chicago", "Houston"],
    "Manager": ["Alice", "Bob", "Carol", "David"]
}
store_info_df = pd.DataFrame(store_info_data)

# Merge the two datasets on 'Store'
merged_df = pd.merge(shop_df, store_info_df, on="Store")

# Drop the 'Location' column
merged_df = merged_df.drop(columns=["Location"])

# Calculate total purchase amount per store
store_totals = merged_df.groupby(["Store", "Manager"])["Purchase Amount (USD)"].sum()

# Find the store with the highest total purchase amount
highest_store = store_totals.idxmax()
highest_amount = store_totals.max()

print("Merged Dataset without 'Location':")
print(merged_df)
print("\nTotal Purchase Amount by Store:")
print(store_totals)
print(f"\nStore with the highest purchase amount: {highest_store}, Amount: ${highest_amount}")
# Out:
# Merged Dataset without 'Location':
#   Customer ID Item Purchased  Purchase Amount (USD)    Store Manager
# 0        C001         Blouse                    200  Store A   Alice
# 1        C002          Shirt                     50  Store B     Bob
# 2        C003          Pants                    300  Store A   Alice
# 3        C004          Skirt                    150  Store C   Carol
# 4        C005          Dress                    400  Store D   David
#
# Total Purchase Amount by Store:
# Store    Manager
# Store A  Alice      500
# Store B  Bob         50
# Store C  Carol      150
# Store D  David      400
# Name: Purchase Amount (USD), dtype: int64
#
# Store with the highest purchase amount: ('Store A', 'Alice'), Amount: $500

# %%
merged_df
# Out:
#   Customer ID Item Purchased  Purchase Amount (USD)    Store Manager
# 0        C001         Blouse                    200  Store A   Alice
# 1        C002          Shirt                     50  Store B     Bob
# 2        C003          Pants                    300  Store A   Alice
# 3        C004          Skirt                    150  Store C   Carol
# 4        C005          Dress                    400  Store D   David

# %% [markdown]
# Let us save and upload our work to Jovian before continuing.

# %%
import jovian

# %%
jovian.commit()

# %% [markdown]
# ## Inferences and Conclusion
#
# # Inferences and Conclusion
#
# This project provided a comprehensive analysis of customer shopping trends, leveraging data cleaning, preparation, and exploratory techniques. Here are the key takeaways and insights derived from the dataset:
#
# ### 1. **Data Cleaning and Preparation**
#    - **Handling Missing and Invalid Data**:
#      - Converted non-numeric or invalid values in columns like "Frequency of Purchases" and "Purchase Amount (USD)" to numeric using `pd.to_numeric()`.
#      - Addressed missing values by filling numerical columns with averages and categorical columns with mode values.
#    - **Improved Data Consistency**:
#      - Ensured alignment and accuracy of columns during operations like filtering and grouping.
#      - Removed rows or columns with excessive missing values when necessary.
#
# ### 2. **Dataset Merging**
#    - **Combining Multiple Datasets**:
#      - Successfully merged customer purchase data (`shopping_df`) with store details (`store_info_df`) using a common key ("Store").
#      - Removed unnecessary columns like "Location" for streamlined analysis.
#    - **Insights from Merging**:
#      - Identified store-level performance, such as total purchase amounts and top-performing managers, enhancing the depth of analysis.
#
# ### 3. **Exploratory Data Analysis**
#    - **Top Purchases**:
#      - High-value items like Dresses and Pants contributed significantly to revenue.
#      - Sorting by purchase amounts revealed customers with the highest spending patterns.
#    - **Category-Based Analysis**:
#      - Clothing categories consistently generated more frequent and higher-value transactions compared to Accessories.
#    - **Gender Insights**:
#      - Female customers dominated spending, especially on items like Blouses and Dresses.
#      - Visualizations highlighted distinct purchasing behaviors between genders.
#    - **Age Analysis**:
#      - Younger customers (aged 22-30) exhibited higher spending on average.
#      - Scatter plots and line charts captured the variations in purchasing behavior across age groups.
#
# ### 4. **Advanced Visualizations**
#    - **Heatmaps**:
#      - Visualized relationships between store attributes and purchase amounts.
#      - Highlighted customer distributions across genders and stores.
#    - **Segmented Analysis**:
#      - Bar charts and grouped visualizations provided a detailed view of spending across categories, seasons, and subscription statuses.
#
# ### Key Insights:
#    - **Revenue Drivers**:
#      - Specific items like Blouses and Dresses were key contributors to total revenue.
#      - Targeting younger and female customers could maximize returns in certain categories.
#    - **Seasonality**:
#      - Spending patterns varied significantly across seasons, with some categories performing better during specific periods.
#    - **Store Performance**:
#      - Store-level analysis pinpointed top-performing locations and managers, guiding resource allocation.
#
# ### Conclusion:
# By cleaning, preparing, and exploring the dataset, we identified actionable insights into customer shopping behaviors. The results can guide business decisions such as product targeting, marketing campaigns, and resource optimization at stores. The project also demonstrates the importance of combining data preparation with advanced visualizations to derive meaningful conclusions.

# %%
import jovian

# %%
jovian.commit()

# %% [markdown]
# ## References and Future Work
#
# - Useful Resources
# Machine Learning & Analytics:
#
# Kaggle Learning Courses: Beginner-friendly tutorials on data analysis and machine learning.
# Scikit-learn Documentation: Comprehensive resource for machine learning techniques in Python.
# Google Colab: Free cloud-based platform for running Python code and experimenting with datasets.
# Visualization:
#
# Matplotlib Documentation: Reference for creating visualizations like bar charts and scatter plots.
# Seaborn Documentation: Useful for advanced and aesthetic statistical visualizations.
# Data Cleaning and Wrangling:
#
# Pandas Official Guide: Detailed tutorials and examples for handling missing data, grouping, and aggregation.
# Books:
#
# "Python for Data Analysis" by Wes McKinney: Focuses on using pandas and numpy for data manipulation and analysis.
# "Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow" by Aurélien Géron: Covers machine learning concepts with practical Python implementations.
# Case Studies and Examples:
#
# Kaggle Competitions: Participate in real-world challenges to refine your skills.
# Analytics Vidhya: Guides and tutorials on data science applications.
#
# dataset was =https://www.kaggle.com/datasets/bhadramohit/customer-shopping-latest-trends-dataset

# %%
import jovian

# %%
jovian.commit()
